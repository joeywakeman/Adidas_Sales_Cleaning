# %% [markdown]
# # Adidas Sales Data Cleaning & Data Wrangling

# %% [markdown]
# In this project, I am going to import a messy dataset of Adidas shoe sales information, clean it, and transform it into a dataset suitable for data analysis.

# %%
import pandas as pd


pd.set_option("display.max.columns",200)

# %%
df = pd.read_excel(r"/Users/josephwakeman/Downloads/Adidas US Sales Datasets.xlsx")
df
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0            NaN          NaN  Adidas Sales Database                  NaN
# 1            NaN          NaN                    NaN                  NaN
# 2            NaN          NaN                    NaN                  NaN
# 3            NaN     Retailer            Retailer ID         Invoice Date
# 4            NaN  Foot Locker                1185732  2020-01-01 00:00:00
# ...          ...          ...                    ...                  ...
# 9647         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9648         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9649         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9650         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9651         NaN  Foot Locker                1185732  2021-02-22 00:00:00
#
#      Unnamed: 4     Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# ...

# %% [markdown]
# ## Renaming the Headers

# %%
df1 = df.rename(columns=df.iloc[3])
df1.head()
# Out:
#    NaN     Retailer            Retailer ID         Invoice Date     Region  \
# 0  NaN          NaN  Adidas Sales Database                  NaN        NaN
# 1  NaN          NaN                    NaN                  NaN        NaN
# 2  NaN          NaN                    NaN                  NaN        NaN
# 3  NaN     Retailer            Retailer ID         Invoice Date     Region
# 4  NaN  Foot Locker                1185732  2020-01-01 00:00:00  Northeast
#
#       State      City                Product  Price per Unit  Units Sold  \
# 0       NaN       NaN                    NaN             NaN         NaN
# 1       NaN       NaN                    NaN             NaN         NaN
# 2       NaN       NaN                    NaN             NaN         NaN
# 3     State      City                Product  Price per Unit  Units Sold
# 4  New York  New York  Men's Street Footwear              50        1200
#
#    Total Sales  Operating Profit  Operating Margin  Sales Method
# ...

# %% [markdown]
# ## Dropping Rows & Columns that Imported as Null from Excel

# %%
df2 = df1.drop(df1.index[:4])
df2.head()
# Out:
#    NaN     Retailer Retailer ID         Invoice Date     Region     State  \
# 4  NaN  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 5  NaN  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 6  NaN  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 7  NaN  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 8  NaN  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total Sales  \
# 4  New York      Men's Street Footwear             50       1200      600000
# 5  New York    Men's Athletic Footwear             50       1000      500000
# 6  New York    Women's Street Footwear             40       1000      400000
# 7  New York  Women's Athletic Footwear             45        850      382500
# 8  New York              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method
# ...

# %%
df3 = df2.dropna(axis=1)
df3.head()
# Out:
#       Retailer Retailer ID         Invoice Date     Region     State  \
# 4  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 5  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 6  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 7  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 8  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total Sales  \
# 4  New York      Men's Street Footwear             50       1200      600000
# 5  New York    Men's Athletic Footwear             50       1000      500000
# 6  New York    Women's Street Footwear             40       1000      400000
# 7  New York  Women's Athletic Footwear             45        850      382500
# 8  New York              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method
# ...

# %%
df4 = df3.reset_index(drop=True)
df4.head()
# Out:
#       Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
#   Operating Profit Operating Margin Sales Method
# ...

# %% [markdown]
# ## Updating Data Types

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: object(13)
# memory usage: 980.0+ KB

# %%
df4[["Retailer ID", "Price per Unit", "Units Sold"]] = df4[["Retailer ID", "Price per Unit", "Units Sold"]].astype(int)

df4[["Price per Unit", "Total Sales", "Operating Profit", "Operating Margin"]] = df4[["Price per Unit", "Total Sales", "Operating Profit", "Operating Margin"]].astype(float)

df4.info()
df4.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 980.0+ KB
#       Retailer  Retailer ID         Invoice Date     Region     State  \
# ...

# %% [markdown]
# ## Standardizing Float Format & Adding Thousands Commas

# %%
pd.set_option("display.float_format", lambda x: "{:,.2f}".format(x))
df4
# Out:
#          Retailer  Retailer ID         Invoice Date     Region          State  \
# 0     Foot Locker      1185732  2020-01-01 00:00:00  Northeast       New York
# 1     Foot Locker      1185732  2020-01-02 00:00:00  Northeast       New York
# 2     Foot Locker      1185732  2020-01-03 00:00:00  Northeast       New York
# 3     Foot Locker      1185732  2020-01-04 00:00:00  Northeast       New York
# 4     Foot Locker      1185732  2020-01-05 00:00:00  Northeast       New York
# ...           ...          ...                  ...        ...            ...
# 9643  Foot Locker      1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9644  Foot Locker      1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9645  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9646  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9647  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %% [markdown]
# ## Replacing Spaces with Underscores in Headers

# %%
df4.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
df5 = df4.rename(columns = {"Retailer ID":"Retailer_ID",
                      "Invoice Date":"Invoice_Date",
                      "Price per Unit":"Price_per_Unit",
                      "Units Sold":"Units_Sold",
                      "Total Sales":"Total_Sales",
                      "Operating Profit":"Operating_Profit",
                      "Operating Margin":"Operating_Margin",
                      "Sales Method":"Sales_Method"})
    
df5.head()
# Out:
#       Retailer  Retailer_ID         Invoice_Date     Region     State  \
# 0  Foot Locker      1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker      1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker      1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker      1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker      1185732  2020-01-05 00:00:00  Northeast  New York
#
#        City                    Product  Price_per_Unit  Units_Sold  \
# 0  New York      Men's Street Footwear           50.00        1200
# 1  New York    Men's Athletic Footwear           50.00        1000
# 2  New York    Women's Street Footwear           40.00        1000
# 3  New York  Women's Athletic Footwear           45.00         850
# 4  New York              Men's Apparel           60.00         900
#
#    Total_Sales  Operating_Profit  Operating_Margin Sales_Method
# 0   600,000.00        300,000.00              0.50     In-store
# ...

# %% [markdown]
# ## Using a Loop to Remove the Timestamps in the Invoice_Date Column

# %%
dates = list()

for x in df5["Invoice_Date"].astype(str):
    y = x.split()
    dates.append(y[0])
    
df5["Invoice_Date"] = dates
df5.head()
# Out:
#       Retailer  Retailer_ID Invoice_Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price_per_Unit  Units_Sold  Total_Sales  \
# 0      Men's Street Footwear           50.00        1200   600,000.00
# 1    Men's Athletic Footwear           50.00        1000   500,000.00
# 2    Women's Street Footwear           40.00        1000   400,000.00
# 3  Women's Athletic Footwear           45.00         850   382,500.00
# 4              Men's Apparel           60.00         900   540,000.00
#
#    Operating_Profit  Operating_Margin Sales_Method
# 0        300,000.00              0.50     In-store
# ...

# %% [markdown]
# ## Using a Loop to Add Separate Day, Month, and Year Columns, Then Placing Them Next to Invoice_Date

# %%
years = list()
months = list()
days = list()

for x in df5["Invoice_Date"]:
    year = x[:4]
    month = x[5:7]
    day = x[8:]
    years.append(year)
    months.append(month)
    days.append(day)
    
df5["Year"] = years
df5["Month"] = months
df5["Day"] = days

df5.head()
# Out:
#       Retailer  Retailer_ID Invoice_Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price_per_Unit  Units_Sold  Total_Sales  \
# 0      Men's Street Footwear           50.00        1200   600,000.00
# 1    Men's Athletic Footwear           50.00        1000   500,000.00
# 2    Women's Street Footwear           40.00        1000   400,000.00
# 3  Women's Athletic Footwear           45.00         850   382,500.00
# 4              Men's Apparel           60.00         900   540,000.00
#
#    Operating_Profit  Operating_Margin Sales_Method  Year Month Day
# ...

# %%
df5.columns
# Out:
# Index(['Retailer', 'Retailer_ID', 'Invoice_Date', 'Region', 'State', 'City',
#        'Product', 'Price_per_Unit', 'Units_Sold', 'Total_Sales',
#        'Operating_Profit', 'Operating_Margin', 'Sales_Method', 'Year', 'Month',
#        'Day'],
#       dtype='object')

# %%
df5 = df5[['Retailer', 'Retailer_ID', 'Invoice_Date', 'Month', 'Day',
       'Year', 'Region', 'State', 'City',
       'Product', 'Price_per_Unit', 'Units_Sold', 'Total_Sales',
       'Operating_Profit', 'Operating_Margin', 'Sales_Method']]
df5.head()
# Out:
#       Retailer  Retailer_ID Invoice_Date Month Day  Year     Region     State  \
# 0  Foot Locker      1185732   2020-01-01    01  01  2020  Northeast  New York
# 1  Foot Locker      1185732   2020-01-02    01  02  2020  Northeast  New York
# 2  Foot Locker      1185732   2020-01-03    01  03  2020  Northeast  New York
# 3  Foot Locker      1185732   2020-01-04    01  04  2020  Northeast  New York
# 4  Foot Locker      1185732   2020-01-05    01  05  2020  Northeast  New York
#
#        City                    Product  Price_per_Unit  Units_Sold  \
# 0  New York      Men's Street Footwear           50.00        1200
# 1  New York    Men's Athletic Footwear           50.00        1000
# 2  New York    Women's Street Footwear           40.00        1000
# 3  New York  Women's Athletic Footwear           45.00         850
# 4  New York              Men's Apparel           60.00         900
#
#    Total_Sales  Operating_Profit  Operating_Margin Sales_Method
# ...

# %% [markdown]
# ## Updating Data Types of New Columns

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer_ID       9648 non-null   int64
#  2   Invoice_Date      9648 non-null   object
#  3   Month             9648 non-null   object
#  4   Day               9648 non-null   object
#  5   Year              9648 non-null   object
#  6   Region            9648 non-null   object
#  7   State             9648 non-null   object
#  8   City              9648 non-null   object
#  9   Product           9648 non-null   object
#  10  Price_per_Unit    9648 non-null   float64
#  11  Units_Sold        9648 non-null   int64
#  12  Total_Sales       9648 non-null   float64
#  13  Operating_Profit  9648 non-null   float64
#  14  Operating_Margin  9648 non-null   float64
#  15  Sales_Method      9648 non-null   object
# ...

# %%
df5[["Year", "Month", "Day"]] = df5[["Year", "Month", "Day"]].astype(int)
df5["Invoice_Date"] = pd.to_datetime(df5["Invoice_Date"])
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer_ID       9648 non-null   int64
#  2   Invoice_Date      9648 non-null   datetime64[ns]
#  3   Month             9648 non-null   int64
#  4   Day               9648 non-null   int64
#  5   Year              9648 non-null   int64
#  6   Region            9648 non-null   object
#  7   State             9648 non-null   object
#  8   City              9648 non-null   object
#  9   Product           9648 non-null   object
#  10  Price_per_Unit    9648 non-null   float64
#  11  Units_Sold        9648 non-null   int64
#  12  Total_Sales       9648 non-null   float64
#  13  Operating_Profit  9648 non-null   float64
#  14  Operating_Margin  9648 non-null   float64
#  15  Sales_Method      9648 non-null   object
# ...

# %% [markdown]
# # Final Product

# %%
df5
# Out:
#          Retailer  Retailer_ID Invoice_Date  Month  Day  Year     Region  \
# 0     Foot Locker      1185732   2020-01-01      1    1  2020  Northeast
# 1     Foot Locker      1185732   2020-01-02      1    2  2020  Northeast
# 2     Foot Locker      1185732   2020-01-03      1    3  2020  Northeast
# 3     Foot Locker      1185732   2020-01-04      1    4  2020  Northeast
# 4     Foot Locker      1185732   2020-01-05      1    5  2020  Northeast
# ...           ...          ...          ...    ...  ...   ...        ...
# 9643  Foot Locker      1185732   2021-01-24      1   24  2021  Northeast
# 9644  Foot Locker      1185732   2021-01-24      1   24  2021  Northeast
# 9645  Foot Locker      1185732   2021-02-22      2   22  2021  Northeast
# 9646  Foot Locker      1185732   2021-02-22      2   22  2021  Northeast
# 9647  Foot Locker      1185732   2021-02-22      2   22  2021  Northeast
#
#               State        City                    Product  Price_per_Unit  \
# ...
